# %%
import os
import h5py
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
def traverse_datasets(hdf5_file):

    """Traverse all datasets across all groups in HDF5 file."""

    def h5py_dataset_iterator(g, prefix=''):
        for key in g.keys():
            item = g[key]
            path = '{}/{}'.format(prefix, key)
            if isinstance(item, h5py.Dataset):  # test for dataset
                yield (path, item)
            elif isinstance(item, h5py.Group):  # test for group (go down)
                yield from h5py_dataset_iterator(item, path)

    with h5py.File(hdf5_file, 'r') as f:
        print("Filename: ", f)
        print("Timestamp: ", f.attrs["OS_time"])
        for (path, dset) in h5py_dataset_iterator(f):
            print(path, dset)

    return None

# %%
#Check Current Working Directory (cwd)
path = '/Volumes/FAT/image_data/'
files = os.listdir(path)
print("Files in : ", path)
print()
for filename in files:
    if filename.endswith(".hdf5"):
    #Open the test file in Current Working Directory
        traverse_datasets(os.path.join(path,filename))
        print()
        print(os.stat(os.path.join(path,filename)).st_size, "bytes \n") #344200 bytes = 0.3442 Megabyte
# Out:
# Files in :  /Volumes/FAT/image_data/
#
# Filename:  <HDF5 file "Capture0.hdf5" (mode r)>
# Timestamp:  15:18:35
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture1.hdf5" (mode r)>
# Timestamp:  15:18:40
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture2.hdf5" (mode r)>
# Timestamp:  15:18:45
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture3.hdf5" (mode r)>
# Timestamp:  15:18:50
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture4.hdf5" (mode r)>
# Timestamp:  15:18:58
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture5.hdf5" (mode r)>
# Timestamp:  15:19:03
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture6.hdf5" (mode r)>
# Timestamp:  15:19:08
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture7.hdf5" (mode r)>
# Timestamp:  15:19:16
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture8.hdf5" (mode r)>
# Timestamp:  15:19:21
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture9.hdf5" (mode r)>
# Timestamp:  15:19:26
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture10.hdf5" (mode r)>
# Timestamp:  15:19:34
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture11.hdf5" (mode r)>
# Timestamp:  15:19:39
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture12.hdf5" (mode r)>
# Timestamp:  15:19:43
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture13.hdf5" (mode r)>
# Timestamp:  15:19:51
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture14.hdf5" (mode r)>
# Timestamp:  15:19:56
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture15.hdf5" (mode r)>
# Timestamp:  15:20:01
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture16.hdf5" (mode r)>
# Timestamp:  15:20:09
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture17.hdf5" (mode r)>
# Timestamp:  15:20:14
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture18.hdf5" (mode r)>
# Timestamp:  15:20:19
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture19.hdf5" (mode r)>
# Timestamp:  15:20:27
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture20.hdf5" (mode r)>
# Timestamp:  15:20:32
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture21.hdf5" (mode r)>
# Timestamp:  15:20:37
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture22.hdf5" (mode r)>
# Timestamp:  15:20:45
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture23.hdf5" (mode r)>
# Timestamp:  15:20:50
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture24.hdf5" (mode r)>
# Timestamp:  15:20:55
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture25.hdf5" (mode r)>
# Timestamp:  15:21:02
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture26.hdf5" (mode r)>
# Timestamp:  15:21:07
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture27.hdf5" (mode r)>
# Timestamp:  15:21:12
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture28.hdf5" (mode r)>
# Timestamp:  15:21:20
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture29.hdf5" (mode r)>
# Timestamp:  15:21:25
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture30.hdf5" (mode r)>
# Timestamp:  15:21:30
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture31.hdf5" (mode r)>
# Timestamp:  15:21:38
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture32.hdf5" (mode r)>
# Timestamp:  15:21:43
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture33.hdf5" (mode r)>
# Timestamp:  15:21:48
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture34.hdf5" (mode r)>
# Timestamp:  15:21:56
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture35.hdf5" (mode r)>
# Timestamp:  15:22:01
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture36.hdf5" (mode r)>
# Timestamp:  15:22:06
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture37.hdf5" (mode r)>
# Timestamp:  15:22:12
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture38.hdf5" (mode r)>
# Timestamp:  15:22:18
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture39.hdf5" (mode r)>
# Timestamp:  15:22:22
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture40.hdf5" (mode r)>
# Timestamp:  15:22:30
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture41.hdf5" (mode r)>
# Timestamp:  15:22:35
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture42.hdf5" (mode r)>
# Timestamp:  15:22:40
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture43.hdf5" (mode r)>
# Timestamp:  15:22:48
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture44.hdf5" (mode r)>
# Timestamp:  15:22:53
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture45.hdf5" (mode r)>
# Timestamp:  15:22:58
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture46.hdf5" (mode r)>
# Timestamp:  15:23:06
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture47.hdf5" (mode r)>
# Timestamp:  15:23:11
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture48.hdf5" (mode r)>
# Timestamp:  15:23:16
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture49.hdf5" (mode r)>
# Timestamp:  15:23:24
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture50.hdf5" (mode r)>
# Timestamp:  15:23:29
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture51.hdf5" (mode r)>
# Timestamp:  15:23:34
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture52.hdf5" (mode r)>
# Timestamp:  15:23:42
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture53.hdf5" (mode r)>
# Timestamp:  15:23:47
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture54.hdf5" (mode r)>
# Timestamp:  15:23:52
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture55.hdf5" (mode r)>
# Timestamp:  15:23:59
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture56.hdf5" (mode r)>
# Timestamp:  15:24:04
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture57.hdf5" (mode r)>
# Timestamp:  15:24:09
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture58.hdf5" (mode r)>
# Timestamp:  15:24:17
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture59.hdf5" (mode r)>
# Timestamp:  15:24:22
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture60.hdf5" (mode r)>
# Timestamp:  15:24:27
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture61.hdf5" (mode r)>
# Timestamp:  15:24:35
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture62.hdf5" (mode r)>
# Timestamp:  15:24:40
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture63.hdf5" (mode r)>
# Timestamp:  15:24:45
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture64.hdf5" (mode r)>
# Timestamp:  15:24:53
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture65.hdf5" (mode r)>
# Timestamp:  15:24:58
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture66.hdf5" (mode r)>
# Timestamp:  15:25:03
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture67.hdf5" (mode r)>
# Timestamp:  15:25:11
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture68.hdf5" (mode r)>
# Timestamp:  15:25:16
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture69.hdf5" (mode r)>
# Timestamp:  15:25:21
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture70.hdf5" (mode r)>
# Timestamp:  15:25:28
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture71.hdf5" (mode r)>
# Timestamp:  15:25:32
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture72.hdf5" (mode r)>
# Timestamp:  15:25:36
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
# Filename:  <HDF5 file "Capture73.hdf5" (mode r)>
# Timestamp:  15:25:44
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture74.hdf5" (mode r)>
# Timestamp:  15:25:49
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture75.hdf5" (mode r)>
# Timestamp:  15:25:54
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture76.hdf5" (mode r)>
# Timestamp:  15:26:02
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture77.hdf5" (mode r)>
# Timestamp:  15:26:07
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture78.hdf5" (mode r)>
# Timestamp:  15:26:15
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture79.hdf5" (mode r)>
# Timestamp:  15:26:20
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture80.hdf5" (mode r)>
# Timestamp:  15:26:25
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture81.hdf5" (mode r)>
# Timestamp:  15:26:33
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture82.hdf5" (mode r)>
# Timestamp:  15:26:38
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture83.hdf5" (mode r)>
# Timestamp:  15:26:43
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture84.hdf5" (mode r)>
# Timestamp:  15:26:51
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture85.hdf5" (mode r)>
# Timestamp:  15:26:56
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture86.hdf5" (mode r)>
# Timestamp:  15:27:01
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture87.hdf5" (mode r)>
# Timestamp:  15:27:09
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture88.hdf5" (mode r)>
# Timestamp:  15:27:14
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture89.hdf5" (mode r)>
# Timestamp:  15:27:19
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture90.hdf5" (mode r)>
# Timestamp:  15:27:27
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture91.hdf5" (mode r)>
# Timestamp:  15:27:32
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture92.hdf5" (mode r)>
# Timestamp:  15:27:37
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture93.hdf5" (mode r)>
# Timestamp:  15:27:45
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture94.hdf5" (mode r)>
# Timestamp:  15:27:50
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture95.hdf5" (mode r)>
# Timestamp:  15:27:55
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture96.hdf5" (mode r)>
# Timestamp:  15:28:03
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture97.hdf5" (mode r)>
# Timestamp:  15:28:08
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture98.hdf5" (mode r)>
# Timestamp:  15:28:13
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture99.hdf5" (mode r)>
# Timestamp:  15:28:20
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture100.hdf5" (mode r)>
# Timestamp:  15:28:25
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
# 33904 bytes
#
# Filename:  <HDF5 file "Capture101.hdf5" (mode r)>
# Timestamp:  15:28:30
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture102.hdf5" (mode r)>
# Timestamp:  15:28:38
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture103.hdf5" (mode r)>
# Timestamp:  15:28:42
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture104.hdf5" (mode r)>
# Timestamp:  15:28:47
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture105.hdf5" (mode r)>
# Timestamp:  15:28:55
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture106.hdf5" (mode r)>
# Timestamp:  15:29:00
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture107.hdf5" (mode r)>
# Timestamp:  15:29:04
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture108.hdf5" (mode r)>
# Timestamp:  15:29:12
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture109.hdf5" (mode r)>
# Timestamp:  15:29:17
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture110.hdf5" (mode r)>
# Timestamp:  15:29:22
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture111.hdf5" (mode r)>
# Timestamp:  15:29:30
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture112.hdf5" (mode r)>
# Timestamp:  15:29:35
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture113.hdf5" (mode r)>
# Timestamp:  15:29:40
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture114.hdf5" (mode r)>
# Timestamp:  15:29:48
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture115.hdf5" (mode r)>
# Timestamp:  15:29:53
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture116.hdf5" (mode r)>
# Timestamp:  15:29:58
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture117.hdf5" (mode r)>
# Timestamp:  15:30:06
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture118.hdf5" (mode r)>
# Timestamp:  15:30:11
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture119.hdf5" (mode r)>
# Timestamp:  15:30:16
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture120.hdf5" (mode r)>
# Timestamp:  15:30:24
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture121.hdf5" (mode r)>
# Timestamp:  15:30:29
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture122.hdf5" (mode r)>
# Timestamp:  15:30:34
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture123.hdf5" (mode r)>
# Timestamp:  15:30:42
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture124.hdf5" (mode r)>
# Timestamp:  15:30:47
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture125.hdf5" (mode r)>
# Timestamp:  15:30:52
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture126.hdf5" (mode r)>
# Timestamp:  15:31:00
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture127.hdf5" (mode r)>
# Timestamp:  15:31:05
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture128.hdf5" (mode r)>
# Timestamp:  15:31:10
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture129.hdf5" (mode r)>
# Timestamp:  15:31:18
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture130.hdf5" (mode r)>
# Timestamp:  15:31:23
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture131.hdf5" (mode r)>
# Timestamp:  15:31:28
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture132.hdf5" (mode r)>
# Timestamp:  15:31:35
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture133.hdf5" (mode r)>
# Timestamp:  15:31:40
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture134.hdf5" (mode r)>
# Timestamp:  15:31:45
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture135.hdf5" (mode r)>
# Timestamp:  15:31:53
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture136.hdf5" (mode r)>
# Timestamp:  15:31:58
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture137.hdf5" (mode r)>
# Timestamp:  15:32:03
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture138.hdf5" (mode r)>
# Timestamp:  15:32:11
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture139.hdf5" (mode r)>
# Timestamp:  15:32:16
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture140.hdf5" (mode r)>
# Timestamp:  15:32:21
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture141.hdf5" (mode r)>
# Timestamp:  15:32:29
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture142.hdf5" (mode r)>
# Timestamp:  15:32:34
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture143.hdf5" (mode r)>
# Timestamp:  15:32:39
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture144.hdf5" (mode r)>
# Timestamp:  15:32:47
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture145.hdf5" (mode r)>
# Timestamp:  15:32:52
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture146.hdf5" (mode r)>
# Timestamp:  15:33:00
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture147.hdf5" (mode r)>
# Timestamp:  15:33:05
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture148.hdf5" (mode r)>
# Timestamp:  15:33:13
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture149.hdf5" (mode r)>
# Timestamp:  15:33:18
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture150.hdf5" (mode r)>
# Timestamp:  15:33:23
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture151.hdf5" (mode r)>
# Timestamp:  15:33:30
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture152.hdf5" (mode r)>
# Timestamp:  15:33:35
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture153.hdf5" (mode r)>
# Timestamp:  15:33:40
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture154.hdf5" (mode r)>
# Timestamp:  15:33:48
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# ...
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture525.hdf5" (mode r)>
# Timestamp:  15:32:46
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture526.hdf5" (mode r)>
# Timestamp:  15:32:54
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture527.hdf5" (mode r)>
# Timestamp:  15:33:00
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture528.hdf5" (mode r)>
# Timestamp:  15:33:05
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture529.hdf5" (mode r)>
# Timestamp:  15:33:13
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture530.hdf5" (mode r)>
# Timestamp:  15:33:18
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture531.hdf5" (mode r)>
# Timestamp:  15:33:23
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture532.hdf5" (mode r)>
# Timestamp:  15:33:31
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture533.hdf5" (mode r)>
# Timestamp:  15:33:36
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture534.hdf5" (mode r)>
# Timestamp:  15:33:44
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture535.hdf5" (mode r)>
# Timestamp:  15:33:50
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture536.hdf5" (mode r)>
# Timestamp:  15:33:55
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture537.hdf5" (mode r)>
# Timestamp:  15:34:03
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture538.hdf5" (mode r)>
# Timestamp:  15:34:08
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture539.hdf5" (mode r)>
# Timestamp:  15:34:13
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture540.hdf5" (mode r)>
# Timestamp:  15:34:21
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture541.hdf5" (mode r)>
# Timestamp:  15:34:27
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture542.hdf5" (mode r)>
# Timestamp:  15:34:32
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture543.hdf5" (mode r)>
# Timestamp:  15:34:39
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture544.hdf5" (mode r)>
# Timestamp:  15:34:44
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture545.hdf5" (mode r)>
# Timestamp:  15:34:49
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture546.hdf5" (mode r)>
# Timestamp:  15:34:57
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture547.hdf5" (mode r)>
# Timestamp:  15:35:02
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture548.hdf5" (mode r)>
# Timestamp:  15:35:10
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture549.hdf5" (mode r)>
# Timestamp:  15:35:16
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture550.hdf5" (mode r)>
# Timestamp:  15:35:21
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture551.hdf5" (mode r)>
# Timestamp:  15:35:29
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture552.hdf5" (mode r)>
# Timestamp:  15:35:34
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture553.hdf5" (mode r)>
# Timestamp:  15:35:39
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture554.hdf5" (mode r)>
# Timestamp:  15:35:47
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture555.hdf5" (mode r)>
# Timestamp:  15:35:53
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture556.hdf5" (mode r)>
# Timestamp:  15:36:01
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture557.hdf5" (mode r)>
# Timestamp:  15:36:06
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture558.hdf5" (mode r)>
# Timestamp:  15:36:11
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture559.hdf5" (mode r)>
# Timestamp:  15:36:19
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture560.hdf5" (mode r)>
# Timestamp:  15:36:24
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture561.hdf5" (mode r)>
# Timestamp:  15:36:32
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture562.hdf5" (mode r)>
# Timestamp:  15:36:38
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture563.hdf5" (mode r)>
# Timestamp:  15:36:43
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture564.hdf5" (mode r)>
# Timestamp:  15:36:51
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture565.hdf5" (mode r)>
# Timestamp:  15:36:56
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture566.hdf5" (mode r)>
# Timestamp:  15:37:01
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture567.hdf5" (mode r)>
# Timestamp:  15:37:09
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture568.hdf5" (mode r)>
# Timestamp:  15:37:14
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture569.hdf5" (mode r)>
# Timestamp:  15:37:23
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture570.hdf5" (mode r)>
# Timestamp:  15:37:28
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture571.hdf5" (mode r)>
# Timestamp:  15:37:33
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture572.hdf5" (mode r)>
# Timestamp:  15:37:41
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture573.hdf5" (mode r)>
# Timestamp:  15:37:46
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture574.hdf5" (mode r)>
# Timestamp:  15:37:54
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes
#
# Filename:  <HDF5 file "Capture575.hdf5" (mode r)>
# Timestamp:  15:38:00
# /image1 <HDF5 dataset "image1": shape (80, 80), type "<u2">
# /image2 <HDF5 dataset "image2": shape (80, 80), type "<u2">
# /temp1 <HDF5 dataset "temp1": shape (), type "<f8">
# /temp2 <HDF5 dataset "temp2": shape (), type "<f8">
#
# 33904 bytes

# %%
def create_df(path, files):
    """
    this script converts hdf5 files in path to a pandas df
    requires filepath to .h5 data and filename
    returns df object
    """
    ims1  = []
    ims2  = []
    t1s   = []
    t2s   = []
    times = []
        
    for f in files:
        if f.endswith(".hdf5"):
            filename = os.path.join(path, f)
            
            #open hdf5 files
            fn = h5py.File(filename, "r")
            e = 'image1' in fn
            if e:
                times.append(fn.attrs["OS_time"])
                ims1.append(fn['image1'][()])
                ims2.append(fn['image2'][()])
                t1s.append(fn['temp1'][()])
                t2s.append(fn['temp2'][()])
        
    return [times,ims1,ims2,t1s,t2s]

# %%
[times,ims1,ims2,t1s,t2s] = create_df(path,files)

# %%
plt.imshow(ims1[20])
plt.colorbar()
plt.show()

# %%
plt.plot(t1s,'.')
plt.plot(t2s,'.')

# %%
plt.plot( np.asarray(ims1)[:,150,150],'.-')
plt.plot( np.asarray(ims1)[:,180,150],'.-')
plt.show()

# %%
plt.plot( np.asarray(ims1)[1,20,:],'.-')
plt.plot( np.asarray(ims1)[60,20,:],'.-')
plt.show()
